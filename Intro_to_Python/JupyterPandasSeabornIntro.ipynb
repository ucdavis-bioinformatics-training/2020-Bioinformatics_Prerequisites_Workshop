# %% [markdown]
# # Welcome to Jupyter!

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook

# %% [markdown]
# # Initial setup
# First we need to get some data to play with, we will use a breast cancer data:
# - [UCI machine learning](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29)
#
# This is a super base level introduction that is truncated from this larger tutorial. I have included only the more important features of the tutorial for brevity. It is definitely worth exploring more.
# - [Medium intro to Pandas for Bioinformatics](https://towardsdatascience.com/pandas-for-biologists-f01c8a548b7c)
#
# We also need to do some initial setup such as install seaborn for plotting and import other libraries

# %%
import os
os.system('wget https://raw.githubusercontent.com/paulocaldas/how-to-python/master/pandas_for_biologists_medium/mydatasets/breast_cancer_diagnostic_data.csv')
# Out:
# 0

# %%
os.system('conda install seaborn')
# Out:
# 0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Playing with and importing the data
# some of the key features to consider, all of which we can not cover in this short section
# - sep
# - header
# - index_col
# - looking at the columns
# - head
# - tail
# - getting one or more columns
# - drop
# - iloc
# - dropna
# - to csv

# %%
breast_cancer_data = pd.read_csv('breast_cancer_diagnostic_data.csv')
breast_cancer_data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %%
breast_cancer_data = pd.read_csv('breast_cancer_diagnostic_data.csv', sep='\t')
breast_cancer_data
# Out:
#     id,"diagnosis","radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean","radius_se","texture_se","perimeter_se","area_se","smoothness_se","compactness_se","concavity_se","concave points_se","symmetry_se","fractal_dimension_se","radius_worst","texture_worst","perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst","concave points_worst","symmetry_worst","fractal_dimension_worst",
# 0    842302,M,17.99,10.38,122.8,1001,0.1184,0.2776,...
# 1    842517,M,20.57,17.77,132.9,1326,0.08474,0.0786...
# 2    84300903,M,19.69,21.25,130,1203,0.1096,0.1599,...
# 3    84348301,M,11.42,20.38,77.58,386.1,0.1425,0.28...
# 4    84358402,M,20.29,14.34,135.1,1297,0.1003,0.132...
# ..                                                 ...
# 564  926424,M,21.56,22.39,142,1479,0.111,0.1159,0.2...
# 565  926682,M,20.13,28.25,131.2,1261,0.0978,0.1034,...
# ...

# %%
breast_cancer_data = pd.read_csv('breast_cancer_diagnostic_data.csv', sep='\t')
breast_cancer_data
# Out:
#     id,"diagnosis","radius_mean","texture_mean","perimeter_mean","area_mean","smoothness_mean","compactness_mean","concavity_mean","concave points_mean","symmetry_mean","fractal_dimension_mean","radius_se","texture_se","perimeter_se","area_se","smoothness_se","compactness_se","concavity_se","concave points_se","symmetry_se","fractal_dimension_se","radius_worst","texture_worst","perimeter_worst","area_worst","smoothness_worst","compactness_worst","concavity_worst","concave points_worst","symmetry_worst","fractal_dimension_worst",
# 0    842302,M,17.99,10.38,122.8,1001,0.1184,0.2776,...
# 1    842517,M,20.57,17.77,132.9,1326,0.08474,0.0786...
# 2    84300903,M,19.69,21.25,130,1203,0.1096,0.1599,...
# 3    84348301,M,11.42,20.38,77.58,386.1,0.1425,0.28...
# 4    84358402,M,20.29,14.34,135.1,1297,0.1003,0.132...
# ..                                                 ...
# 564  926424,M,21.56,22.39,142,1479,0.111,0.1159,0.2...
# 565  926682,M,20.13,28.25,131.2,1261,0.0978,0.1034,...
# ...

# %%
breast_cancer_data = pd.read_csv('breast_cancer_diagnostic_data.csv', sep=',')
breast_cancer_data
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# # Filtering and manipulating the dataframe

# %%
breast_cancer_data.shape
# Out:
# (569, 33)

# %%
breast_cancer_data[breast_cancer_data['diagnosis'] == "M"].shape
# Out:
# (212, 33)

# %%
breast_cancer_data[breast_cancer_data['diagnosis'] == "B"].shape
# Out:
# (357, 33)

# %%
breast_cancer_data[breast_cancer_data['radius_mean'] >= 12].shape
# Out:
# (400, 33)

# %%
breast_cancer_data[breast_cancer_data['radius_mean'] < 12].shape
# Out:
# (169, 33)

# %%
breast_cancer_data[(breast_cancer_data['diagnosis'] == "M") & (breast_cancer_data['radius_mean'] >= 12)].shape
# Out:
# (206, 33)

# %%
breast_cancer_data.groupby('diagnosis').corr()
# Out:
#                                          id  radius_mean  texture_mean  \
# diagnosis
# B         id                       1.000000    -0.032465      0.043933
#           radius_mean             -0.032465     1.000000     -0.037150
#           texture_mean             0.043933    -0.037150      1.000000
#           perimeter_mean          -0.036449     0.996769     -0.039923
#           area_mean               -0.026036     0.994435     -0.039055
# ...                                     ...          ...           ...
# M         concavity_worst         -0.018537     0.069621      0.110075
#           concave points_worst     0.035155     0.383461     -0.002213
#           symmetry_worst          -0.146282    -0.266375     -0.087386
#           fractal_dimension_worst -0.096551    -0.383367      0.025960
#           Unnamed: 32                   NaN          NaN           NaN
#
#                                    perimeter_mean  area_mean  smoothness_mean  \
# diagnosis
# ...

# %% [markdown]
# # Graphing with seaborn

# %%
# create a subtable containing all the rows and the first 7 columns 
breast_cancer_data_subset = breast_cancer_data.iloc[:, :8]

# we discard the columns containing patient id (we don't need here)
breast_cancer_data_subset.drop('id', axis = 1, inplace = True)

# we rename the columns with better/shorter names
# we do this by passing a new list of names
breast_cancer_data_subset.columns = ['diagnosis', 'radius', 'texture', 'perimeter','area', 'smoothness', 'compactness']
sns.pairplot(breast_cancer_data_subset, hue = 'diagnosis')

# %%
sns.scatterplot(data=breast_cancer_data, x = 'radius_mean', y = 'texture_mean', hue='diagnosis');
